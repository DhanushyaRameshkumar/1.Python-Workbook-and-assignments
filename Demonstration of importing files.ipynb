# %%
from VariousFunctionsLib import Variousfunctions

# %%
Variousfunctions.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neutral Network
# vision
# Robotics
# Speech Processing
# NLP

# %%
Variousfunctions.OddEven()
# Out:
# Enter a number:88
# 88 is Even number

# %%
Variousfunctions.ElegibilityForMarriage()
# Out:
# Your gender:Female
# Your Age:22
# ELIGIBLE

# %%
Variousfunctions.Precentage()
# Out:
# Subject1=98
# Subject2=87
# Subject3=95
# Subject4=95
# Subject5=93
# Total: 468
# Percentage: 93.6

# %%
Variousfunctions.triangle()
# Out:
# Height:32
# Breadth:34
# Area formula:(Height*Breadth)/2)
# Area of Triangle: 544.0
# Height1:2
# Height2:4
# Breadth:4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10.0
